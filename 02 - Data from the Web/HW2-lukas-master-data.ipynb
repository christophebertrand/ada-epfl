# %%
# imports (may be more than needed)
import pandas as pd
import numpy as np
import glob # to find all files in folder
from datetime import datetime
from datetime import date, time
from dateutil.parser import parse
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
# %matplotlib inline
sns.set_context('notebook')
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# #  Master Data
# _Obtain all the data for the Bachelor students, starting from 2007. Keep only the students for which you have an entry for both Bachelor semestre 1 and Bachelor semestre 6. Compute how many months it took each student to go from the first to the sixth semester. Partition the data between male and female students, and compute the average -- is the difference in average statistically significant?_
#
#
# 2) Perform a similar operation to what described above, this time for Master students. Notice that this data is more tricky, as there are many missing records in the IS-Academia database. Therefore, try to guess how much time a master student spent at EPFL by at least checking the distance in months between Master semestre 1 and Master semestre 2. If the Mineur field is not empty, the student should also appear registered in Master semestre 3. Last but not the least, don't forget to check if the student has an entry also in the Projet Master tables. Once you can handle well this data, compute the "average stay at EPFL" for master students. Now extract all the students with a Spécialisation and compute the "average stay" per each category of that attribute -- compared to the general average, can you find any specialization for which the difference in average is statistically significant?

# %% [markdown]
# ## Read the data from csv

# %%
all_data = pd.read_csv('all_data.csv', usecols=['Civilité', 'Nom_Prénom', 'title', 'periode_acad', 'periode_pedago','Orientation_Master', 'Spécialisation', 'Filière_opt.', 'Mineur', 'Statut', 'Type_Echange', 'Ecole_Echange', 'No_Sciper'])

# %%
all_data.sort_values(by='No_Sciper', axis=0)
# Out:
#       Civilité                                         Nom_Prénom  \
# 7567  Monsieur                                      Martin Damien
# 8828  Monsieur                                     Gulati Asheesh
# 8602  Monsieur                                     Gulati Asheesh
# 8870  Monsieur                                         Zhou Maoan
# 8654  Monsieur                                         Zhou Maoan
# 7563  Monsieur                                  Essellak Radouane
# 8848  Monsieur                                     Ni Zhong Zhong
# 8631  Monsieur                                     Ni Zhong Zhong
# 8407  Monsieur                            Droz-dit-Busset Arnault
# 8813  Monsieur                               Clivaz Jean-Philippe
# 8658  Monsieur                                      Hügli Michael
# 8833  Monsieur                                      Hügli Michael
# 3325  Monsieur                                   Cardinaux Damien
# 8402  Monsieur                                   Cardinaux Damien
# 8586  Monsieur                                   Cardinaux Damien
# 8831    Madame                                   Henriot Laetitia
# 2943  Monsieur                                       Marx Clément
# 327   Monsieur                                       Marx Clément
# 2702  Monsieur                                       Marx Clément
# 8021  Monsieur                                       Marx Clément
# 8269  Monsieur                                       Marx Clément
# 3133  Monsieur                                       Marx Clément
# 550   Monsieur                                       Marx Clément
# 8817  Monsieur                                   De Lamarter Erik
# 8425  Monsieur                                      Junod Antoine
# 8611  Monsieur                                      Junod Antoine
# 7593  Monsieur                                        Good Xavier
# 7872  Monsieur                                        Good Xavier
# 3249  Monsieur                                        Good Xavier
# 2990  Monsieur                                        Good Xavier
# ...        ...                                                ...
# 7178  Monsieur                               Iseli Lucien Michaël
# 7176    Madame                                      Idrizi Gonxhe
# 7193  Monsieur                                       Krcmar Peter
# 7149  Monsieur                                   Friedli Jonathan
# 7147  Monsieur                             Fournier Julien Marcel
# 7151  Monsieur                                     Fusi Noah Duoc
# 7204  Monsieur                             Luisier Gabriel Xavier
# 7227  Monsieur                           Nejad Sattary Kamran Ali
# 7231  Monsieur                    Ottaviani Lorenzo Antonio Maria
# 7261  Monsieur                           Servat Jean-Marc Patrick
# 7132  Monsieur                                Dumoulin Paul Milan
# 7113  Monsieur                               Cochard Victor Angel
# 7175  Monsieur                                          Hu Julien
# 7094  Monsieur                                          Boujo Max
# 7291  Monsieur                            Wilders Eric Bruno John
# 7296  Monsieur                         Zeller Corentin Luc Claude
# 7274  Monsieur  Thierry D'Argenlieu Nicolas Alain Alexandre Marie
# 7423  Monsieur                              Fraj-Sladoljev Patrik
# 7511  Monsieur                                         Böhm Felix
# 7425  Monsieur                                    Gulberti Andrea
# 7109  Monsieur                      Chappuis Sébastien Max Roland
# 7447    Madame                                      Zhang Hailing
# 7421    Madame                 Eriksson Jacqueline Larissa Linnea
# 7427  Monsieur                                      Hasani Xhulio
# 7156  Monsieur                                     Geinoz Grégory
# 7448    Madame                                      Zhao Zhengrui
# 7437  Monsieur                                      Marver Robert
# 7428  Monsieur                                    Joshi Chaitanya
# 7446    Madame                                          Wu Yutong
# 7431  Monsieur                                    Ljubenkov Davor
#
#       Orientation_Master                  Spécialisation Filière_opt. Mineur  \
# 7567                 NaN                             NaN          NaN    NaN
# 8828                 NaN              Internet computing          NaN    NaN
# 8602                 NaN              Internet computing          NaN    NaN
# 8870                 NaN                             NaN          NaN    NaN
# 8654                 NaN                             NaN          NaN    NaN
# 7563                 NaN                             NaN          NaN    NaN
# 8848                 NaN                             NaN          NaN    NaN
# 8631                 NaN                             NaN          NaN    NaN
# 8407                 NaN                             NaN          NaN    NaN
# 8813                 NaN                             NaN          NaN    NaN
# 8658                 NaN                             NaN          NaN    NaN
# 8833                 NaN                             NaN          NaN    NaN
# 3325                 NaN                             NaN          NaN    NaN
# 8402                 NaN                             NaN          NaN    NaN
# 8586                 NaN                             NaN          NaN    NaN
# 8831                 NaN                             NaN          NaN    NaN
# 2943                 NaN  Signals, Images and Interfaces          NaN    NaN
# 327                  NaN  Signals, Images and Interfaces          NaN    NaN
# 2702                 NaN  Signals, Images and Interfaces          NaN    NaN
# 8021                 NaN                             NaN          NaN    NaN
# 8269                 NaN  Signals, Images and Interfaces          NaN    NaN
# 3133                 NaN  Signals, Images and Interfaces          NaN    NaN
# 550                  NaN  Signals, Images and Interfaces          NaN    NaN
# 8817                 NaN                             NaN          NaN    NaN
# 8425                 NaN                             NaN          NaN    NaN
# 8611                 NaN                             NaN          NaN    NaN
# 7593                 NaN                             NaN          NaN    NaN
# 7872                 NaN                             NaN          NaN    NaN
# 3249                 NaN                             NaN          NaN    NaN
# 2990                 NaN                             NaN          NaN    NaN
# ...                  ...                             ...          ...    ...
# 7178                 NaN                             NaN          NaN    NaN
# 7176                 NaN                             NaN          NaN    NaN
# 7193                 NaN                             NaN          NaN    NaN
# 7149                 NaN                             NaN          NaN    NaN
# 7147                 NaN                             NaN          NaN    NaN
# 7151                 NaN                             NaN          NaN    NaN
# 7204                 NaN                             NaN          NaN    NaN
# 7227                 NaN                             NaN          NaN    NaN
# 7231                 NaN                             NaN          NaN    NaN
# 7261                 NaN                             NaN          NaN    NaN
# 7132                 NaN                             NaN          NaN    NaN
# 7113                 NaN                             NaN          NaN    NaN
# 7175                 NaN                             NaN          NaN    NaN
# 7094                 NaN                             NaN          NaN    NaN
# 7291                 NaN                             NaN          NaN    NaN
# 7296                 NaN                             NaN          NaN    NaN
# 7274                 NaN                             NaN          NaN    NaN
# 7423                 NaN                             NaN          NaN    NaN
# 7511                 NaN                             NaN          NaN    NaN
# 7425                 NaN                             NaN          NaN    NaN
# 7109                 NaN                             NaN          NaN    NaN
# 7447                 NaN                             NaN          NaN    NaN
# 7421                 NaN                             NaN          NaN    NaN
# 7427                 NaN                             NaN          NaN    NaN
# 7156                 NaN                             NaN          NaN    NaN
# 7448                 NaN                             NaN          NaN    NaN
# 7437                 NaN                             NaN          NaN    NaN
# 7428                 NaN                             NaN          NaN    NaN
# 7446                 NaN                             NaN          NaN    NaN
# 7431                 NaN                             NaN          NaN    NaN
#
#        Statut Type_Echange                                   Ecole_Echange  \
# 7567  Présent          NaN                                             NaN
# 8828  Présent          NaN                                             NaN
# 8602  Présent          NaN                                             NaN
# 8870    Stage          NaN                                             NaN
# 8654  Présent          NaN                                             NaN
# 7563  Présent          NaN                                             NaN
# 8848  Présent          NaN                                             NaN
# 8631  Présent          NaN                                             NaN
# 8407  Présent          NaN                                             NaN
# 8813  Présent          NaN                                             NaN
# 8658    Stage          NaN                                             NaN
# 8833  Présent          NaN                                             NaN
# 3325  Présent          NaN                                             NaN
# 8402  Présent          NaN                                             NaN
# 8586  Présent          NaN                                             NaN
# 8831  Présent          NaN                                             NaN
# 2943  Présent          NaN                                             NaN
# 327   Présent          NaN                                             NaN
# 2702  Présent          NaN                                             NaN
# 8021    Congé          NaN                                             NaN
# 8269  Présent          NaN                                             NaN
# 3133  Présent          NaN                                             NaN
# 550   Présent          NaN                                             NaN
# 8817  Présent          NaN                                             NaN
# 8425  Présent          NaN                                             NaN
# 8611  Présent          NaN                                             NaN
# 7593    Congé    Bilatéral           Carnegie Mellon University Pittsburgh
# 7872    Congé    Bilatéral           Carnegie Mellon University Pittsburgh
# 3249  Présent          NaN                                             NaN
# 2990  Présent          NaN                                             NaN
# ...       ...          ...                                             ...
# 7178  Présent          NaN                                             NaN
# 7176  Présent          NaN                                             NaN
# 7193  Présent          NaN                                             NaN
# 7149  Présent          NaN                                             NaN
# 7147  Présent          NaN                                             NaN
# 7151  Présent          NaN                                             NaN
# 7204  Présent          NaN                                             NaN
# 7227  Présent          NaN                                             NaN
# 7231  Présent          NaN                                             NaN
# 7261  Présent          NaN                                             NaN
# 7132  Présent          NaN                                             NaN
# 7113  Présent          NaN                                             NaN
# 7175  Présent          NaN                                             NaN
# 7094  Présent          NaN                                             NaN
# 7291  Présent          NaN                                             NaN
# 7296  Présent          NaN                                             NaN
# 7274  Présent          NaN                                             NaN
# 7423  Présent      Erasmus                            University of Zagreb
# 7511  Présent      Erasmus                   Technische Universität Berlin
# 7425  Présent      Erasmus               Università degli Studi di Trieste
# 7109  Présent          NaN                                             NaN
# 7447  Présent    Bilatéral                National University of Singapore
# 7421  Présent      Erasmus  Royal Institute of Technology, (KTH) Stockholm
# 7427  Présent    Bilatéral                 Ecole Polytechnique de Montréal
# 7156  Présent          NaN                                             NaN
# 7448  Présent      Erasmus                                       INSA Lyon
# 7437  Présent    Bilatéral               University of Washington, Seattle
# 7428  Présent    Bilatéral                Nanyang Technological University
# 7446  Présent    Bilatéral                          University of Waterloo
# 7431  Présent      Erasmus                             University of Split
#
#       No_Sciper                                             title  \
# 7567     121367  Passerelle HES - IN, 2016-2017, Semestre automne
# 8828     128911        Informatique, 2007-2008, Master semestre 3
# 8602     128911        Informatique, 2007-2008, Master semestre 2
# 8870     129093        Informatique, 2007-2008, Master semestre 3
# 8654     129093        Informatique, 2007-2008, Master semestre 2
# 7563     129094  Passerelle HES - IN, 2016-2017, Semestre automne
# 8848     129326        Informatique, 2007-2008, Master semestre 3
# 8631     129326        Informatique, 2007-2008, Master semestre 2
# 8407     138088        Informatique, 2007-2008, Master semestre 1
# 8813     145546        Informatique, 2007-2008, Master semestre 3
# 8658     145957  Informatique, 2007-2008, Projet Master printemps
# 8833     145957        Informatique, 2007-2008, Master semestre 3
# 3325     146330        Informatique, 2008-2009, Master semestre 3
# 8402     146330        Informatique, 2007-2008, Master semestre 1
# 8586     146330        Informatique, 2007-2008, Master semestre 2
# 8831     146441        Informatique, 2007-2008, Master semestre 3
# 2943     146742        Informatique, 2008-2009, Master semestre 1
# 327      146742        Informatique, 2009-2010, Master semestre 2
# 2702     146742        Informatique, 2012-2013, Master semestre 3
# 8021     146742  Informatique, 2010-2011, Projet Master printemps
# 8269     146742    Informatique, 2010-2011, Projet Master automne
# 3133     146742        Informatique, 2008-2009, Master semestre 2
# 550      146742        Informatique, 2009-2010, Master semestre 3
# 8817     146752        Informatique, 2007-2008, Master semestre 3
# 8425     146929        Informatique, 2007-2008, Master semestre 1
# 8611     146929        Informatique, 2007-2008, Master semestre 2
# 7593     147008      Informatique, 2010-2011, Bachelor semestre 5
# 7872     147008      Informatique, 2010-2011, Bachelor semestre 6
# 3249     147008      Informatique, 2008-2009, Bachelor semestre 1
# 2990     147008      Informatique, 2008-2009, Bachelor semestre 2
# ...         ...                                               ...
# 7178     274999      Informatique, 2016-2017, Bachelor semestre 1
# 7176     275001      Informatique, 2016-2017, Bachelor semestre 1
# 7193     275071      Informatique, 2016-2017, Bachelor semestre 1
# 7149     275102      Informatique, 2016-2017, Bachelor semestre 1
# 7147     275105      Informatique, 2016-2017, Bachelor semestre 1
# 7151     275116      Informatique, 2016-2017, Bachelor semestre 1
# 7204     275142      Informatique, 2016-2017, Bachelor semestre 1
# 7227     275159      Informatique, 2016-2017, Bachelor semestre 1
# 7231     275199      Informatique, 2016-2017, Bachelor semestre 1
# 7261     275273      Informatique, 2016-2017, Bachelor semestre 1
# 7132     275313      Informatique, 2016-2017, Bachelor semestre 1
# 7113     275383      Informatique, 2016-2017, Bachelor semestre 1
# 7175     275553      Informatique, 2016-2017, Bachelor semestre 1
# 7094     275608      Informatique, 2016-2017, Bachelor semestre 1
# 7291     276016      Informatique, 2016-2017, Bachelor semestre 1
# 7296     276323      Informatique, 2016-2017, Bachelor semestre 1
# 7274     276507      Informatique, 2016-2017, Bachelor semestre 1
# 7423     276543         Echange IN, 2016-2017, Semestre printemps
# 7511     276596           Echange IN, 2016-2017, Semestre automne
# 7425     276709         Echange IN, 2016-2017, Semestre printemps
# 7109     276937      Informatique, 2016-2017, Bachelor semestre 1
# 7447     277017         Echange IN, 2016-2017, Semestre printemps
# 7421     277018         Echange IN, 2016-2017, Semestre printemps
# 7427     277028         Echange IN, 2016-2017, Semestre printemps
# 7156     277113      Informatique, 2016-2017, Bachelor semestre 1
# 7448     277442         Echange IN, 2016-2017, Semestre printemps
# 7437     278455         Echange IN, 2016-2017, Semestre printemps
# 7428     278479         Echange IN, 2016-2017, Semestre printemps
# 7446     278495         Echange IN, 2016-2017, Semestre printemps
# 7431     278496         Echange IN, 2016-2017, Semestre printemps
#
#      periode_acad           periode_pedago
# 7567    2016-2017         Semestre automne
# 8828    2007-2008        Master semestre 3
# 8602    2007-2008        Master semestre 2
# 8870    2007-2008        Master semestre 3
# 8654    2007-2008        Master semestre 2
# 7563    2016-2017         Semestre automne
# 8848    2007-2008        Master semestre 3
# 8631    2007-2008        Master semestre 2
# 8407    2007-2008        Master semestre 1
# 8813    2007-2008        Master semestre 3
# 8658    2007-2008  Projet Master printemps
# 8833    2007-2008        Master semestre 3
# 3325    2008-2009        Master semestre 3
# 8402    2007-2008        Master semestre 1
# 8586    2007-2008        Master semestre 2
# 8831    2007-2008        Master semestre 3
# 2943    2008-2009        Master semestre 1
# 327     2009-2010        Master semestre 2
# 2702    2012-2013        Master semestre 3
# 8021    2010-2011  Projet Master printemps
# 8269    2010-2011    Projet Master automne
# 3133    2008-2009        Master semestre 2
# 550     2009-2010        Master semestre 3
# 8817    2007-2008        Master semestre 3
# 8425    2007-2008        Master semestre 1
# 8611    2007-2008        Master semestre 2
# 7593    2010-2011      Bachelor semestre 5
# 7872    2010-2011      Bachelor semestre 6
# 3249    2008-2009      Bachelor semestre 1
# 2990    2008-2009      Bachelor semestre 2
# ...           ...                      ...
# 7178    2016-2017      Bachelor semestre 1
# 7176    2016-2017      Bachelor semestre 1
# 7193    2016-2017      Bachelor semestre 1
# 7149    2016-2017      Bachelor semestre 1
# 7147    2016-2017      Bachelor semestre 1
# 7151    2016-2017      Bachelor semestre 1
# 7204    2016-2017      Bachelor semestre 1
# 7227    2016-2017      Bachelor semestre 1
# 7231    2016-2017      Bachelor semestre 1
# 7261    2016-2017      Bachelor semestre 1
# 7132    2016-2017      Bachelor semestre 1
# 7113    2016-2017      Bachelor semestre 1
# 7175    2016-2017      Bachelor semestre 1
# 7094    2016-2017      Bachelor semestre 1
# 7291    2016-2017      Bachelor semestre 1
# 7296    2016-2017      Bachelor semestre 1
# 7274    2016-2017      Bachelor semestre 1
# 7423    2016-2017       Semestre printemps
# 7511    2016-2017         Semestre automne
# 7425    2016-2017       Semestre printemps
# 7109    2016-2017      Bachelor semestre 1
# 7447    2016-2017       Semestre printemps
# 7421    2016-2017       Semestre printemps
# 7427    2016-2017       Semestre printemps
# 7156    2016-2017      Bachelor semestre 1
# 7448    2016-2017       Semestre printemps
# 7437    2016-2017       Semestre printemps
# 7428    2016-2017       Semestre printemps
# 7446    2016-2017       Semestre printemps
# 7431    2016-2017       Semestre printemps
#
# [8942 rows x 13 columns]

# %%
len(all_data)
# Out:
# 8942

# %% [markdown]
# ## Clean the data

# %%
all_data['periode_pedago'].unique()
# Out:
# array(['Bachelor semestre 5', 'Master semestre 1', 'Bachelor semestre 2',
#        'Bachelor semestre 6', 'Master semestre 2',
#        'Projet Master printemps', 'Bachelor semestre 3',
#        'Bachelor semestre 1', 'Master semestre 3', 'Semestre printemps',
#        'Projet Master automne', 'Semestre automne', 'Bachelor semestre 4'], dtype=object)

# %%
all_data['title'].unique()
# Out:
# array(['Informatique, 2009-2010, Bachelor semestre 5',
#        'Informatique, 2009-2010, Master semestre 1',
#        'Informatique, 2009-2010, Bachelor semestre 2',
#        'Informatique, 2009-2010, Bachelor semestre 6',
#        'Informatique, 2009-2010, Master semestre 2',
#        'Informatique, 2009-2010, Projet Master printemps',
#        'Informatique, 2009-2010, Bachelor semestre 3',
#        'Informatique, 2009-2010, Bachelor semestre 1',
#        'Informatique, 2009-2010, Master semestre 3',
#        'Passerelle HES - IN, 2009-2010, Semestre printemps',
#        'Informatique, 2009-2010, Projet Master automne',
#        'Passerelle HES - IN, 2009-2010, Semestre automne',
#        'Echange IN, 2009-2010, Semestre automne',
#        'Informatique, 2009-2010, Bachelor semestre 4',
#        'Informatique, 2014-2015, Bachelor semestre 5',
#        'Informatique, 2014-2015, Master semestre 1',
#        'Informatique, 2014-2015, Bachelor semestre 2',
#        'Informatique, 2014-2015, Bachelor semestre 6',
#        'Informatique, 2014-2015, Master semestre 2',
#        'Informatique, 2014-2015, Bachelor semestre 3',
#        'Informatique, 2014-2015, Bachelor semestre 1',
#        'Informatique, 2014-2015, Master semestre 3',
#        'Passerelle HES - IN, 2014-2015, Semestre printemps',
#        'Echange IN, 2014-2015, Semestre printemps',
#        'Informatique, 2014-2015, Projet Master automne',
#        'Passerelle HES - IN, 2014-2015, Semestre automne',
#        'Echange IN, 2014-2015, Semestre automne',
#        'Informatique, 2014-2015, Bachelor semestre 4',
#        'Informatique, 2012-2013, Bachelor semestre 5',
#        'Informatique, 2012-2013, Master semestre 1',
#        'Informatique, 2012-2013, Bachelor semestre 2',
#        'Informatique, 2012-2013, Bachelor semestre 6',
#        'Informatique, 2012-2013, Master semestre 2',
#        'Informatique, 2012-2013, Projet Master printemps',
#        'Informatique, 2012-2013, Bachelor semestre 3',
#        'Informatique, 2012-2013, Bachelor semestre 1',
#        'Informatique, 2012-2013, Master semestre 3',
#        'Passerelle HES - IN, 2012-2013, Semestre printemps',
#        'Informatique, 2012-2013, Projet Master automne',
#        'Passerelle HES - IN, 2012-2013, Semestre automne',
#        'Echange IN, 2012-2013, Semestre automne',
#        'Informatique, 2012-2013, Bachelor semestre 4',
#        'Informatique, 2008-2009, Bachelor semestre 5',
#        'Informatique, 2008-2009, Master semestre 1',
#        'Informatique, 2008-2009, Bachelor semestre 2',
#        'Informatique, 2008-2009, Bachelor semestre 6',
#        'Informatique, 2008-2009, Master semestre 2',
#        'Informatique, 2008-2009, Projet Master printemps',
#        'Passerelle HES - IN, 2008-2009, Bachelor semestre 3',
#        'Informatique, 2008-2009, Bachelor semestre 3',
#        'Informatique, 2008-2009, Bachelor semestre 1',
#        'Informatique, 2008-2009, Master semestre 3',
#        'Echange IN, 2008-2009, Semestre printemps',
#        'Informatique, 2008-2009, Projet Master automne',
#        'Echange IN, 2008-2009, Semestre automne',
#        'Informatique, 2008-2009, Bachelor semestre 4',
#        'Passerelle HES - IN, 2008-2009, Bachelor semestre 4',
#        'Informatique, 2015-2016, Bachelor semestre 5',
#        'Informatique, 2015-2016, Master semestre 1',
#        'Informatique, 2015-2016, Bachelor semestre 2',
#        'Informatique, 2015-2016, Bachelor semestre 6',
#        'Informatique, 2015-2016, Master semestre 2',
#        'Informatique, 2015-2016, Bachelor semestre 3',
#        'Informatique, 2015-2016, Bachelor semestre 1',
#        'Informatique, 2015-2016, Master semestre 3',
#        'Passerelle HES - IN, 2015-2016, Semestre printemps',
#        'Echange IN, 2015-2016, Semestre printemps',
#        'Informatique, 2015-2016, Projet Master automne',
#        'Echange IN, 2015-2016, Semestre automne',
#        'Passerelle HES - IN, 2015-2016, Semestre automne',
#        'Informatique, 2015-2016, Bachelor semestre 4',
#        'Informatique, 2011-2012, Bachelor semestre 5',
#        'Informatique, 2011-2012, Master semestre 1',
#        'Informatique, 2011-2012, Bachelor semestre 2',
#        'Informatique, 2011-2012, Bachelor semestre 6',
#        'Informatique, 2011-2012, Master semestre 2',
#        'Informatique, 2011-2012, Projet Master printemps',
#        'Informatique, 2011-2012, Bachelor semestre 3',
#        'Informatique, 2011-2012, Bachelor semestre 1',
#        'Informatique, 2011-2012, Master semestre 3',
#        'Passerelle HES - IN, 2011-2012, Semestre printemps',
#        'Echange IN, 2011-2012, Semestre printemps',
#        'Informatique, 2011-2012, Projet Master automne',
#        'Passerelle HES - IN, 2011-2012, Semestre automne',
#        'Echange IN, 2011-2012, Semestre automne',
#        'Informatique, 2011-2012, Bachelor semestre 4',
#        'Informatique, 2013-2014, Bachelor semestre 5',
#        'Informatique, 2013-2014, Master semestre 1',
#        'Informatique, 2013-2014, Bachelor semestre 2',
#        'Informatique, 2013-2014, Bachelor semestre 6',
#        'Informatique, 2013-2014, Master semestre 2',
#        'Informatique, 2013-2014, Projet Master printemps',
#        'Informatique, 2013-2014, Bachelor semestre 3',
#        'Informatique, 2013-2014, Bachelor semestre 1',
#        'Informatique, 2013-2014, Master semestre 3',
#        'Passerelle HES - IN, 2013-2014, Semestre printemps',
#        'Echange IN, 2013-2014, Semestre printemps',
#        'Informatique, 2013-2014, Projet Master automne',
#        'Echange IN, 2013-2014, Semestre automne',
#        'Passerelle HES - IN, 2013-2014, Semestre automne',
#        'Informatique, 2013-2014, Bachelor semestre 4',
#        'Informatique, 2016-2017, Bachelor semestre 5',
#        'Informatique, 2016-2017, Master semestre 1',
#        'Informatique, 2016-2017, Bachelor semestre 2',
#        'Informatique, 2016-2017, Bachelor semestre 6',
#        'Informatique, 2016-2017, Master semestre 2',
#        'Informatique, 2016-2017, Bachelor semestre 3',
#        'Informatique, 2016-2017, Bachelor semestre 1',
#        'Informatique, 2016-2017, Master semestre 3',
#        'Echange IN, 2016-2017, Semestre printemps',
#        'Informatique, 2016-2017, Projet Master automne',
#        'Echange IN, 2016-2017, Semestre automne',
#        'Passerelle HES - IN, 2016-2017, Semestre automne',
#        'Informatique, 2016-2017, Bachelor semestre 4',
#        'Informatique, 2010-2011, Bachelor semestre 5',
#        'Informatique, 2010-2011, Master semestre 1',
#        'Informatique, 2010-2011, Bachelor semestre 2',
#        'Informatique, 2010-2011, Bachelor semestre 6',
#        'Informatique, 2010-2011, Master semestre 2',
#        'Informatique, 2010-2011, Projet Master printemps',
#        'Informatique, 2010-2011, Bachelor semestre 3',
#        'Informatique, 2010-2011, Bachelor semestre 1',
#        'Informatique, 2010-2011, Master semestre 3',
#        'Echange IN, 2010-2011, Semestre printemps',
#        'Informatique, 2010-2011, Projet Master automne',
#        'Echange IN, 2010-2011, Semestre automne',
#        'Passerelle HES - IN, 2010-2011, Semestre automne',
#        'Informatique, 2010-2011, Bachelor semestre 4',
#        'Informatique, 2007-2008, Bachelor semestre 5',
#        'Informatique, 2007-2008, Master semestre 1',
#        'Informatique, 2007-2008, Bachelor semestre 2',
#        'Informatique, 2007-2008, Bachelor semestre 6',
#        'Informatique, 2007-2008, Master semestre 2',
#        'Informatique, 2007-2008, Projet Master printemps',
#        'Informatique, 2007-2008, Bachelor semestre 3',
#        'Passerelle HES - IN, 2007-2008, Bachelor semestre 3',
#        'Informatique, 2007-2008, Bachelor semestre 1',
#        'Informatique, 2007-2008, Master semestre 3',
#        'Echange IN, 2007-2008, Semestre printemps',
#        'Informatique, 2007-2008, Projet Master automne',
#        'Echange IN, 2007-2008, Semestre automne',
#        'Passerelle HES - IN, 2007-2008, Bachelor semestre 4',
#        'Informatique, 2007-2008, Bachelor semestre 4'], dtype=object)

# %% [markdown]
# checkout what the Semester printemps and automne are

# %%
all_data[all_data['periode_pedago'].isin(['Semestre printemps', 'Semestre automne'])]['title'].unique()
# Out:
# array(['Passerelle HES - IN, 2009-2010, Semestre printemps',
#        'Passerelle HES - IN, 2009-2010, Semestre automne',
#        'Echange IN, 2009-2010, Semestre automne',
#        'Passerelle HES - IN, 2014-2015, Semestre printemps',
#        'Echange IN, 2014-2015, Semestre printemps',
#        'Passerelle HES - IN, 2014-2015, Semestre automne',
#        'Echange IN, 2014-2015, Semestre automne',
#        'Passerelle HES - IN, 2012-2013, Semestre printemps',
#        'Passerelle HES - IN, 2012-2013, Semestre automne',
#        'Echange IN, 2012-2013, Semestre automne',
#        'Echange IN, 2008-2009, Semestre printemps',
#        'Echange IN, 2008-2009, Semestre automne',
#        'Passerelle HES - IN, 2015-2016, Semestre printemps',
#        'Echange IN, 2015-2016, Semestre printemps',
#        'Echange IN, 2015-2016, Semestre automne',
#        'Passerelle HES - IN, 2015-2016, Semestre automne',
#        'Passerelle HES - IN, 2011-2012, Semestre printemps',
#        'Echange IN, 2011-2012, Semestre printemps',
#        'Passerelle HES - IN, 2011-2012, Semestre automne',
#        'Echange IN, 2011-2012, Semestre automne',
#        'Passerelle HES - IN, 2013-2014, Semestre printemps',
#        'Echange IN, 2013-2014, Semestre printemps',
#        'Echange IN, 2013-2014, Semestre automne',
#        'Passerelle HES - IN, 2013-2014, Semestre automne',
#        'Echange IN, 2016-2017, Semestre printemps',
#        'Echange IN, 2016-2017, Semestre automne',
#        'Passerelle HES - IN, 2016-2017, Semestre automne',
#        'Echange IN, 2010-2011, Semestre printemps',
#        'Echange IN, 2010-2011, Semestre automne',
#        'Passerelle HES - IN, 2010-2011, Semestre automne',
#        'Echange IN, 2007-2008, Semestre printemps',
#        'Echange IN, 2007-2008, Semestre automne'], dtype=object)

# %% [markdown]
# This are the students in exchange (epfl students in exchange somewhere else) and students doing the Passerelle HES. As the students in exchange are in thir 3rd year Bachelor we ignore them. Also we won't count students in Passerelle HES as beeing in the Master just yet because they have to succeed the passerelle to optain a master. So if they do a master they are inscribed in Master anyways.

# %%
master_periode_pedago = ['Master semestre 1', 'Master semestre 2', 'Projet Master printemps', 'Master semestre 3', 'Projet Master automne']
master_data = all_data[all_data['periode_pedago'].isin(master_periode_pedago)]

# %% [markdown]
# remove the columns with only NaN (in case there is one)

# %%
master_data.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# Rename the columns (remove the é and give shorter names)

# %%
master_data.rename(columns={'Civilité': 'Sex', 'Nom_Prénom': 'Name', 'Spécialisation': 'Specialisation'}, inplace=True)

# %%
master_data['periode_pedago'].unique()
# Out:
# array(['Master semestre 1', 'Master semestre 2', 'Projet Master printemps',
#        'Master semestre 3', 'Projet Master automne'], dtype=object)

# %% [markdown]
# add some columns that make the use of the data easier later
# - store the start and end year of each entry ('2008-2009' -> 2008) and '2008-2009' -> 2009
# - make a column for master1, master2, master3 and and project master and indicate if done it (true and false)

# %%
master_data['periode_acad'].unique()
# Out:
# array(['2009-2010', '2014-2015', '2012-2013', '2008-2009', '2015-2016',
#        '2011-2012', '2013-2014', '2016-2017', '2010-2011', '2007-2008'], dtype=object)

# %%
# store the year of the entry
def start_year(student):
    return int (student['periode_acad'].split('-')[0])
master_data['start_year'] = master_data.apply(start_year, axis=1)
master_data['end_year'] = master_data.apply(lambda st: start_year(st)+1, axis=1)

# %%
# make the indicator columns
new_cols_map = {
    'Master1': ['Master semestre 1'],
    'Master2': ['Master semestre 2'],
    'Master3': ['Master semestre 3'],
    'Project_Master' : ['Projet Master printemps', 'Projet Master automne']
}
for (new_col_name, match_list) in new_cols_map.items():
    master_data[new_col_name] = master_data.apply(lambda student: student['periode_pedago'] in match_list, axis=1)

# %%
# show the new master_data (sample randomly to keep it managable but still informative)
master_data.sample(n = 10, axis=0, replace=False)
# Out:
#            Sex                          Name             Specialisation  \
# 2965  Monsieur                  Züger Walter                        NaN
# 7941  Monsieur                 Ecuyer Adrien         Internet computing
# 3594  Monsieur  Dubedat Philippe Pierre-Elie                        NaN
# 544     Madame                    Ilie Diana  Computer Engineering - SP
# 2947  Monsieur            Nguyen-Xuan Jérémy                        NaN
# 4796    Madame                      Kim Miji                        NaN
# 865   Monsieur           Schmid Georg Stefan                        NaN
# 1170    Madame        Bagcioglu Egeyar Özlen         Internet computing
# 6938  Monsieur               Tâche Guillaume                        NaN
# 6035  Monsieur                    Angel Axel                        NaN
#
#      Mineur   Statut Type_Echange  \
# 2965    NaN    Congé      Erasmus
# 7941    NaN  Présent          NaN
# 3594    NaN  Présent          NaN
# 544     NaN  Présent          NaN
# 2947    NaN  Présent          NaN
# 4796    NaN  Présent          NaN
# 865     NaN  Présent          NaN
# 1170    NaN  Présent          NaN
# 6938    NaN  Présent          NaN
# 6035    NaN  Présent          NaN
#
#                                        Ecole_Echange  No_Sciper  \
# 2965  Royal Institute of Technology, (KTH) Stockholm     171042
# 7941                                             NaN     176061
# 3594                                             NaN     259766
# 544                                              NaN     185005
# 2947                                             NaN     167386
# 4796                                             NaN     200932
# 865                                              NaN     244618
# 1170                                             NaN     232468
# 6938                                             NaN     239124
# 6035                                             NaN     201284
#
#                                            title periode_acad  \
# 2965  Informatique, 2008-2009, Master semestre 1    2008-2009
# 7941  Informatique, 2010-2011, Master semestre 2    2010-2011
# 3594  Informatique, 2015-2016, Master semestre 1    2015-2016
# 544   Informatique, 2009-2010, Master semestre 3    2009-2010
# 2947  Informatique, 2008-2009, Master semestre 1    2008-2009
# 4796  Informatique, 2011-2012, Master semestre 1    2011-2012
# 865   Informatique, 2014-2015, Master semestre 1    2014-2015
# 1170  Informatique, 2014-2015, Master semestre 2    2014-2015
# 6938  Informatique, 2016-2017, Master semestre 1    2016-2017
# 6035  Informatique, 2013-2014, Master semestre 2    2013-2014
#
#          periode_pedago  start_year  end_year Master1 Project_Master Master3  \
# 2965  Master semestre 1        2008      2009    True          False   False
# 7941  Master semestre 2        2010      2011   False          False   False
# 3594  Master semestre 1        2015      2016    True          False   False
# 544   Master semestre 3        2009      2010   False          False    True
# 2947  Master semestre 1        2008      2009    True          False   False
# 4796  Master semestre 1        2011      2012    True          False   False
# 865   Master semestre 1        2014      2015    True          False   False
# 1170  Master semestre 2        2014      2015   False          False   False
# 6938  Master semestre 1        2016      2017    True          False   False
# 6035  Master semestre 2        2013      2014   False          False   False
#
#      Master2
# 2965   False
# 7941    True
# 3594   False
# 544    False
# 2947   False
# 4796   False
# 865    False
# 1170    True
# 6938   False
# 6035    True

# %% [markdown]
# We will remove all students that did certainly not finish the master. That is we remove students that:
# - Did only 1 semester
# - Have a mineur or spez and did less than 3 semesters.
#
# We also remove students that already have been studiing in 2007 (the start of our data) because we can not tell if how long they already have studied before.

# %%
# find all students that have not done the 'master 1' semester -> have not studied enough to finish the master.
grouped = master_data.groupby(by='No_Sciper')
no_master_1 = pd.DataFrame(columns=['Civilité', 'Nom_Prénom', 'Orientation_Bachelor', 'Orientation_Master',
      'Spécialisation', 'Filière_opt.', 'Mineur', 'Statut', 'Type_Echange',
      'Ecole_Echange', 'No_Sciper', 'title', 'periode_acad',
      'periode_pedago']) 
for scip, group in grouped:
    if (group.periode_pedago != 'Master semestre 1').all():
        no_master_1 = pd.concat([no_master_1, group])
len(no_master_1.No_Sciper.unique())
# Out:
# 76

# %%
# all the students that already studied in the '2007-2008' year:
df_2006 = no_master_1[no_master_1.periode_acad == '2007-2008']
len(df_2006.No_Sciper.unique())
# Out:
# 66

# %% [markdown]
# remove the found students

# %%
sciper_to_remove = no_master_1['No_Sciper'].unique()
master_data = master_data[~master_data['No_Sciper'].isin(sciper_to_remove)]

# %% [markdown]
# #### Groupby and aggregate by student

# %%
def group_master_data(grouped_entries):
    # check that there are no two students with the same sciper number
    must_be_unique_list = ['Sex', 'Name'] #No_Scyper also but we group by it -> unique by definition
    #if(len(grouped_entries[unique_col].unique()) > 1): raise ValueError('Two students of different '+unique_col+' with same No_Sciper') for unique_col in must_be_unique_list]
    
    #aggregate the cols
    first_entry = grouped_entries.head(1)
    df_map = {
        'No_Sciper' : first_entry['No_Sciper'].values[0],
        'Name' : first_entry['Name'].values[0],
        'Sex' : first_entry['Sex'].values[0],
        'Specialisation' : grouped_entries['Specialisation'].dropna().unique(),
        'Mineur' : grouped_entries['Mineur'].dropna().unique(),
        'first_year': grouped_entries['start_year'].min(), # smallest start year entry
        'last_year' : grouped_entries['end_year'].max(), # highest year a studend appears (eg 2010)
        'first_semestre' : grouped_entries.sort_values(by=['start_year', 'periode_pedago'], axis=0, ascending=True)['periode_pedago'].values[0], # eg master1
        'last_semestre' : grouped_entries.sort_values(by=['end_year', 'periode_pedago'], axis=0, ascending=False)['periode_pedago'].values[0], # the name of the last semester (eg. master 3)
        'semesters_done' : grouped_entries.sort_values(by=['end_year'])['periode_pedago'].values,
        'nombre_semestres' : len(grouped_entries) # how many different semesters the student did at epfl
    }
    
    # if there are two spez, take the latest one
    if len(df_map['Specialisation']) > 1:
        print(df_map['No_Sciper'])
        df_map['Specialisation'] = grouped_entries[grouped_entries['end_year'] == df_map['last_year']]['Specialisation']
    elif len(df_map['Specialisation']) == 1:
        df_map['Specialisation'] = df_map['Specialisation'][0]
        
    # set correct nans
    if len(df_map['Mineur']) == 0:
        df_map['Mineur'] = np.nan
    if len(df_map['Specialisation']) == 0:
        df_map['Specialisation'] = np.nan
    
    # make Dataframe
    for (k, v) in df_map.items():
        df_map[k] = [v]
    return pd.DataFrame.from_dict(df_map)
    
    
grouped_master = master_data.groupby(by='No_Sciper', as_index=False, sort=True).apply(group_master_data)
grouped_master.head()
# Out:
# 175703
# 180570
# 184264
# 204253
# 261006
#     Mineur                     Name  No_Sciper       Sex  \
# 0 0    NaN  Droz-dit-Busset Arnault     138088  Monsieur
# 1 0    NaN         Cardinaux Damien     146330  Monsieur
# 2 0    NaN             Marx Clément     146742  Monsieur
# 3 0    NaN            Junod Antoine     146929  Monsieur
# 4 0    NaN              Good Xavier     147008  Monsieur
#
#                      Specialisation     first_semestre  first_year  \
# 0 0                             NaN  Master semestre 1        2007
# 1 0                             NaN  Master semestre 1        2007
# 2 0  Signals, Images and Interfaces  Master semestre 1        2008
# 3 0                             NaN  Master semestre 1        2007
# 4 0  Signals, Images and Interfaces  Master semestre 1        2011
#
#          last_semestre  last_year  nombre_semestres  \
# 0 0  Master semestre 1       2008                 1
# 1 0  Master semestre 3       2009                 3
# 2 0  Master semestre 3       2013                 7
# 3 0  Master semestre 2       2008                 2
# 4 0  Master semestre 3       2013                 4
#
#                                         semesters_done
# 0 0                                [Master semestre 1]
# 1 0  [Master semestre 1, Master semestre 2, Master ...
# 2 0  [Master semestre 1, Master semestre 2, Master ...
# 3 0             [Master semestre 1, Master semestre 2]
# 4 0  [Master semestre 1, Master semestre 2, Master ...

# %%
grouped_master.set_index('No_Sciper', inplace=True)
grouped_master
# Out:
#                                                       Mineur  \
# No_Sciper
# 138088                                                   NaN
# 146330                                                   NaN
# 146742                                                   NaN
# 146929                                                   NaN
# 147008                                                   NaN
# 152232     [Mineur en Management, technologie et entrepre...
# 153066                                                   NaN
# 153746                                                   NaN
# 153762                                                   NaN
# 154080                                                   NaN
# 154573                                                   NaN
# 154643                                                   NaN
# 154706                                                   NaN
# 155018                                                   NaN
# 155097                                                   NaN
# 159516                                                   NaN
# 159998                                                   NaN
# 160148                                                   NaN
# 160213                                                   NaN
# 160225                                                   NaN
# 160254                                                   NaN
# 160492                                                   NaN
# 160578                                                   NaN
# 160718                                                   NaN
# 160893                                                   NaN
# 160991                                                   NaN
# 161024                                                   NaN
# 161091                                                   NaN
# 161127                                                   NaN
# 161138                                                   NaN
# ...                                                      ...
# 268907                                                   NaN
# 268910                                                   NaN
# 269057                                                   NaN
# 269096                                                   NaN
# 269098                                                   NaN
# 269369                                                   NaN
# 269412                                                   NaN
# 269423                                                   NaN
# 269467                                                   NaN
# 271189                                                   NaN
# 271331                                                   NaN
# 271711                                                   NaN
# 271965                                                   NaN
# 272025                                                   NaN
# 272086                                                   NaN
# 272324                                                   NaN
# 272509                                                   NaN
# 272620                                                   NaN
# 272783                                                   NaN
# 272785                                                   NaN
# 272817                                                   NaN
# 273006                                                   NaN
# 273101                                                   NaN
# 273107                                                   NaN
# 273118                                                   NaN
# 273156                                                   NaN
# 273163                                                   NaN
# 273182                                                   NaN
# 273251                                                   NaN
# 273563                                                   NaN
#
#                                                         Name       Sex  \
# No_Sciper
# 138088                               Droz-dit-Busset Arnault  Monsieur
# 146330                                      Cardinaux Damien  Monsieur
# 146742                                          Marx Clément  Monsieur
# 146929                                         Junod Antoine  Monsieur
# 147008                                           Good Xavier  Monsieur
# 152232                                    Anagnostaras David  Monsieur
# 153066                             Aeberhard François-Xavier  Monsieur
# 153746                                          Cassina Ilya  Monsieur
# 153762                                          Conus Johann  Monsieur
# 154080                                   Fomene Tierry Alain  Monsieur
# 154573                                    Benabdallah Zeineb    Madame
# 154643                                           Dumont Loïc  Monsieur
# 154706                                        Suter François  Monsieur
# 155018                                          Signori Jean  Monsieur
# 155097                                               Wei Zhe  Monsieur
# 159516                                           Raja Yanick  Monsieur
# 159998                                           Jesse Julia    Madame
# 160148                                       Casati Nathalie    Madame
# 160213                                    Bécholey Alexandre  Monsieur
# 160225                                     Cassata Alexandre  Monsieur
# 160254                                         Kohler Johann  Monsieur
# 160492                                           Bettex Marc  Monsieur
# 160578                                        Gascon Grégory  Monsieur
# 160718                                     Copponnex Hadrien  Monsieur
# 160893                                Ngallemo Hever Patrick  Monsieur
# 160991                                        Schintgen Joël  Monsieur
# 161024                                       Meinen Jennifer    Madame
# 161091                                      Grivet Ekaterina    Madame
# 161127                                         Sahy François  Monsieur
# 161138                                      Sauthier Ludovic  Monsieur
# ...                                                      ...       ...
# 268907                                       Dimovski Mladen  Monsieur
# 268910                                      Hendrikx Hadrien  Monsieur
# 269057                                           Zhang Weiyu    Madame
# 269096                                 Tomoiaga Ciprian-Ioan  Monsieur
# 269098                                         Petri Vincent  Monsieur
# 269369                                    Bhattacharyya Atri  Monsieur
# 269412                                          Kjosev Tasho  Monsieur
# 269423                                         Najdenova Iva    Madame
# 269467                                      Shevchenko Artem  Monsieur
# 271189                                      Tresch Christian  Monsieur
# 271331                                      Adams Marc Alain  Monsieur
# 271711                                     Martinelli Mattia  Monsieur
# 271965                            Holloway Alexander Patrick  Monsieur
# 272025                                        El Zein Yamane    Madame
# 272086                                            Nie Shiyue    Madame
# 272324                            Colombo Pierre Jean Adrien  Monsieur
# 272509                                        Sacchi Niccolò  Monsieur
# 272620                               Gotmare Akhilesh Deepak  Monsieur
# 272783                         Launay Clément Hervé Stéphane  Monsieur
# 272785     Le Tourneux De La Perraudiere Valentin Marie Marc  Monsieur
# 272817                                   Kuziora Marta Kinga    Madame
# 273006                                             Yin Wensi    Madame
# 273101                                       Adamsons Valdis  Monsieur
# 273107                           Aquil Mohammad Amimul Ihsan  Monsieur
# 273118                                      Barbera Antonino  Monsieur
# 273156                        Champenois Bertrand Brice Marc  Monsieur
# 273163                            del Marmol Syméon Marie J.  Monsieur
# 273182                                      Vasiliu Valentin  Monsieur
# 273251                                          Pavllo Dario  Monsieur
# 273563                                           Yiue Ya-Lan    Madame
#
#                            Specialisation     first_semestre  first_year  \
# No_Sciper
# 138088                                NaN  Master semestre 1        2007
# 146330                                NaN  Master semestre 1        2007
# 146742     Signals, Images and Interfaces  Master semestre 1        2008
# 146929                                NaN  Master semestre 1        2007
# 147008     Signals, Images and Interfaces  Master semestre 1        2011
# 152232                                NaN  Master semestre 1        2007
# 153066                 Internet computing  Master semestre 1        2007
# 153746                                NaN  Master semestre 1        2007
# 153762                                NaN  Master semestre 1        2008
# 154080                 Internet computing  Master semestre 1        2007
# 154573                       Biocomputing  Master semestre 1        2007
# 154643                                NaN  Master semestre 1        2007
# 154706                                NaN  Master semestre 1        2007
# 155018                                NaN  Master semestre 1        2007
# 155097                                NaN  Master semestre 1        2007
# 159516                                NaN  Master semestre 1        2008
# 159998     Signals, Images and Interfaces  Master semestre 1        2008
# 160148                                NaN  Master semestre 1        2007
# 160213                                NaN  Master semestre 2        2007
# 160225                                NaN  Master semestre 1        2007
# 160254                 Internet computing  Master semestre 1        2007
# 160492                                NaN  Master semestre 1        2007
# 160578                                NaN  Master semestre 1        2007
# 160718            Foundations of Software  Master semestre 1        2007
# 160893                                NaN  Master semestre 1        2007
# 160991                 Internet computing  Master semestre 1        2007
# 161024                                NaN  Master semestre 1        2007
# 161091                                NaN  Master semestre 1        2008
# 161127                                NaN  Master semestre 1        2008
# 161138                                NaN  Master semestre 1        2007
# ...                                   ...                ...         ...
# 268907                                NaN  Master semestre 1        2016
# 268910                                NaN  Master semestre 1        2016
# 269057                                NaN  Master semestre 1        2016
# 269096                     Data Analytics  Master semestre 1        2016
# 269098                                NaN  Master semestre 1        2016
# 269369                                NaN  Master semestre 1        2016
# 269412                                NaN  Master semestre 1        2016
# 269423                                NaN  Master semestre 1        2016
# 269467                                NaN  Master semestre 1        2016
# 271189                                NaN  Master semestre 1        2016
# 271331                                NaN  Master semestre 1        2016
# 271711                                NaN  Master semestre 1        2016
# 271965                                NaN  Master semestre 1        2016
# 272025                                NaN  Master semestre 1        2016
# 272086                                NaN  Master semestre 1        2016
# 272324                                NaN  Master semestre 1        2016
# 272509                                NaN  Master semestre 1        2016
# 272620                                NaN  Master semestre 1        2016
# 272783                                NaN  Master semestre 1        2016
# 272785                                NaN  Master semestre 1        2016
# 272817                                NaN  Master semestre 1        2016
# 273006                                NaN  Master semestre 1        2016
# 273101                                NaN  Master semestre 1        2016
# 273107            Foundations of Software  Master semestre 1        2016
# 273118                                NaN  Master semestre 1        2016
# 273156                                NaN  Master semestre 1        2016
# 273163                                NaN  Master semestre 1        2016
# 273182                                NaN  Master semestre 1        2016
# 273251                                NaN  Master semestre 1        2016
# 273563                                NaN  Master semestre 1        2016
#
#                      last_semestre  last_year  nombre_semestres  \
# No_Sciper
# 138088           Master semestre 1       2008                 1
# 146330           Master semestre 3       2009                 3
# 146742           Master semestre 3       2013                 7
# 146929           Master semestre 2       2008                 2
# 147008           Master semestre 3       2013                 4
# 152232           Master semestre 3       2009                 3
# 153066           Master semestre 3       2010                 6
# 153746           Master semestre 1       2009                 3
# 153762           Master semestre 3       2010                 4
# 154080           Master semestre 3       2010                 5
# 154573     Projet Master printemps       2010                 6
# 154643           Master semestre 2       2008                 2
# 154706           Master semestre 3       2009                 3
# 155018           Master semestre 2       2008                 2
# 155097           Master semestre 3       2009                 3
# 159516     Projet Master printemps       2010                 4
# 159998           Master semestre 3       2010                 3
# 160148           Master semestre 3       2009                 3
# 160213     Projet Master printemps       2010                 5
# 160225     Projet Master printemps       2009                 4
# 160254           Master semestre 3       2009                 3
# 160492           Master semestre 2       2008                 2
# 160578           Master semestre 3       2009                 3
# 160718           Master semestre 3       2009                 3
# 160893           Master semestre 3       2009                 3
# 160991           Master semestre 3       2009                 3
# 161024           Master semestre 2       2008                 2
# 161091           Master semestre 3       2010                 4
# 161127           Master semestre 1       2010                 3
# 161138           Master semestre 2       2008                 2
# ...                            ...        ...               ...
# 268907           Master semestre 1       2017                 1
# 268910           Master semestre 1       2017                 1
# 269057           Master semestre 1       2017                 1
# 269096           Master semestre 1       2017                 1
# 269098           Master semestre 1       2017                 1
# 269369           Master semestre 1       2017                 1
# 269412           Master semestre 1       2017                 1
# 269423           Master semestre 1       2017                 1
# 269467           Master semestre 1       2017                 1
# 271189           Master semestre 1       2017                 1
# 271331           Master semestre 1       2017                 1
# 271711           Master semestre 1       2017                 1
# 271965           Master semestre 1       2017                 1
# 272025           Master semestre 1       2017                 1
# 272086           Master semestre 1       2017                 1
# 272324           Master semestre 1       2017                 1
# 272509           Master semestre 1       2017                 1
# 272620           Master semestre 1       2017                 1
# 272783           Master semestre 1       2017                 1
# 272785           Master semestre 1       2017                 1
# 272817           Master semestre 1       2017                 1
# 273006           Master semestre 1       2017                 1
# 273101           Master semestre 1       2017                 1
# 273107           Master semestre 1       2017                 1
# 273118           Master semestre 1       2017                 1
# 273156           Master semestre 1       2017                 1
# 273163           Master semestre 1       2017                 1
# 273182           Master semestre 1       2017                 1
# 273251           Master semestre 1       2017                 1
# 273563           Master semestre 1       2017                 1
#
#                                               semesters_done
# No_Sciper
# 138088                                   [Master semestre 1]
# 146330     [Master semestre 1, Master semestre 2, Master ...
# 146742     [Master semestre 1, Master semestre 2, Master ...
# 146929                [Master semestre 1, Master semestre 2]
# 147008     [Master semestre 1, Master semestre 2, Master ...
# 152232     [Master semestre 1, Master semestre 2, Master ...
# 153066     [Master semestre 1, Master semestre 2, Master ...
# 153746     [Master semestre 1, Master semestre 2, Master ...
# 153762     [Master semestre 1, Master semestre 2, Master ...
# 154080     [Master semestre 1, Master semestre 2, Master ...
# 154573     [Master semestre 1, Master semestre 2, Master ...
# 154643                [Master semestre 1, Master semestre 2]
# 154706     [Master semestre 1, Master semestre 2, Master ...
# 155018                [Master semestre 1, Master semestre 2]
# 155097     [Master semestre 1, Master semestre 2, Master ...
# 159516     [Master semestre 1, Master semestre 2, Projet ...
# 159998     [Master semestre 1, Master semestre 2, Master ...
# 160148     [Master semestre 1, Master semestre 2, Master ...
# 160213     [Master semestre 2, Master semestre 1, Master ...
# 160225     [Master semestre 1, Master semestre 2, Projet ...
# 160254     [Master semestre 1, Master semestre 2, Master ...
# 160492                [Master semestre 1, Master semestre 2]
# 160578     [Master semestre 1, Master semestre 2, Master ...
# 160718     [Master semestre 1, Master semestre 2, Master ...
# 160893     [Master semestre 1, Master semestre 2, Master ...
# 160991     [Master semestre 1, Master semestre 2, Master ...
# 161024                [Master semestre 1, Master semestre 2]
# 161091     [Master semestre 1, Master semestre 2, Master ...
# 161127     [Master semestre 1, Master semestre 2, Master ...
# 161138                [Master semestre 1, Master semestre 2]
# ...                                                      ...
# 268907                                   [Master semestre 1]
# 268910                                   [Master semestre 1]
# 269057                                   [Master semestre 1]
# 269096                                   [Master semestre 1]
# 269098                                   [Master semestre 1]
# 269369                                   [Master semestre 1]
# 269412                                   [Master semestre 1]
# 269423                                   [Master semestre 1]
# 269467                                   [Master semestre 1]
# 271189                                   [Master semestre 1]
# 271331                                   [Master semestre 1]
# 271711                                   [Master semestre 1]
# 271965                                   [Master semestre 1]
# 272025                                   [Master semestre 1]
# 272086                                   [Master semestre 1]
# 272324                                   [Master semestre 1]
# 272509                                   [Master semestre 1]
# 272620                                   [Master semestre 1]
# 272783                                   [Master semestre 1]
# 272785                                   [Master semestre 1]
# 272817                                   [Master semestre 1]
# 273006                                   [Master semestre 1]
# 273101                                   [Master semestre 1]
# 273107                                   [Master semestre 1]
# 273118                                   [Master semestre 1]
# 273156                                   [Master semestre 1]
# 273163                                   [Master semestre 1]
# 273182                                   [Master semestre 1]
# 273251                                   [Master semestre 1]
# 273563                                   [Master semestre 1]
#
# [901 rows x 10 columns]

# %% [markdown]
# ## How many month did it take each student

# %% [markdown]
# ## And per specialisation

# %% [markdown]
# ## Female vs Male
